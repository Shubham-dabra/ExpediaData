# %%
storage_account_name = "expedia3"
client_id = "6f03e4a1-be1a-46f6-a33d-acdbab80f744"
tenant_id = "b41b72d0-4e9f-4c26-8a69-f949f367c91d"
client_secret = "YP37Q~sZHJ-hCTkXj1yi-.8xpV92dulFUspJK"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
configs = {"fs.azure.account.auth.type": "OAuth",
"fs.azure.account.oauth.provider.type": "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
"fs.azure.account.oauth2.client.id": f"{client_id}",
"fs.azure.account.oauth2.client.secret": f"{client_secret}",
"fs.azure.account.oauth2.client.endpoint": f"https://login.microsoftonline.com/{tenant_id}/oauth2/token"}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
container_name = "expediasource"
dbutils.fs.mount(
source = f"abfss://{container_name}@{storage_account_name}.dfs.core.windows.net/",
mount_point = f"/mnt/{storage_account_name}/{container_name}",
extra_configs = configs)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[21]: True</div>

# %%
dbutils.fs.ls("/mnt/expedia3/expediasource")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[23]: [FileInfo(path=&#39;dbfs:/mnt/expedia3/expediasource/part-00000-ef2b800c-0702-462d-b37f-5f2fb3a093d0-c000.avro&#39;, name=&#39;part-00000-ef2b800c-0702-462d-b37f-5f2fb3a093d0-c000.avro&#39;, size=5517132),
#  FileInfo(path=&#39;dbfs:/mnt/expedia3/expediasource/part-00001-ef2b800c-0702-462d-b37f-5f2fb3a093d0-c000.avro&#39;, name=&#39;part-00001-ef2b800c-0702-462d-b37f-5f2fb3a093d0-c000.avro&#39;, size=5540585),
#  FileInfo(path=&#39;dbfs:/mnt/expedia3/expediasource/part-00002-ef2b800c-0702-462d-b37f-5f2fb3a093d0-c000.avro&#39;, name=&#39;part-00002-ef2b800c-0702-462d-b37f-5f2fb3a093d0-c000.avro&#39;, size=5542617)]</div>

# %%
from pyspark.sql.types import *

df=spark.read.format("avro").option("inferSchema","True").load("/mnt/expedia3/expediasource/*.avro")
df1= df.limit(20000)
df1.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>date_time</th><th>site_name</th><th>posa_continent</th><th>user_location_country</th><th>user_location_region</th><th>user_location_city</th><th>orig_destination_distance</th><th>user_id</th><th>is_mobile</th><th>is_package</th><th>channel</th><th>srch_ci</th><th>srch_co</th><th>srch_adults_cnt</th><th>srch_children_cnt</th><th>srch_rm_cnt</th><th>srch_destination_id</th><th>srch_destination_type_id</th><th>hotel_id</th></tr></thead><tbody><tr><td>10</td><td>2015-11-08 17:43:50</td><td>2</td><td>3</td><td>66</td><td>311</td><td>48189</td><td>2660.9654</td><td>51</td><td>0</td><td>0</td><td>10</td><td>2017-08-05</td><td>2017-08-06</td><td>2</td><td>0</td><td>1</td><td>12267</td><td>6</td><td>2697239461889</td></tr><tr><td>99</td><td>2015-09-22 20:40:50</td><td>2</td><td>3</td><td>66</td><td>174</td><td>5938</td><td>933.3503</td><td>405</td><td>0</td><td>1</td><td>10</td><td>2017-09-22</td><td>2017-09-25</td><td>2</td><td>2</td><td>1</td><td>8273</td><td>1</td><td>944892805127</td></tr><tr><td>120</td><td>2015-08-06 06:30:37</td><td>2</td><td>3</td><td>198</td><td>208</td><td>54488</td><td>null</td><td>456</td><td>0</td><td>0</td><td>0</
# %%
# %python
jdbcHostname="test-server25.database.windows.net"
jdbcDatabase="SQL_Database25"
jdbcusername="sqladm25"
jdbcpassword="sqladm.1*"
jdbcport="1433"
table="expedia1"
jdbcUrl="jdbc:sqlserver://{0}:{1};database={2}".format(jdbcHostname,jdbcport,jdbcDatabase)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df1.write.mode("overwrite") \
.format("jdbc")  \
.option("url",jdbcUrl) \
.option("dbtable",table) \
.option("user", jdbcusername) \
.option("password", jdbcpassword) \
.option("driver", "com.microsoft.sqlserver.jdbc.SQLServerDriver") \
.save()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
create table incrementalinfo(
tablename string,
start_time timestamp)
USING DELTA;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
insert into table incrementalinfo values('expedia1',cast('1900-01-01' as date))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr></tbody></table></div>

# %%
# %sql
select * from incrementalinfo;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>tablename</th><th>start_time</th></tr></thead><tbody><tr><td>expedia1</td><td>1900-01-01T00:00:00.000+0000</td></tr></tbody></table></div>

# %%
import time
ts =time.time()
import datetime
ts1= spark.sql("select start_time from incrementalinfo where tablename= 'expedia1'").collect()[0][0].strftime('%Y-%m-%d %H:%M:%S')
query= "(select * from dbo.expedia1 where date_time>=cast('{0}' as datetime) ) z".format(ts1)
today1= datetime.datetime.fromtimestamp(ts).strftime('%Y-%m-%d %H:%M:%S')
today1
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[3]: &#39;2021-12-16 08:04:04&#39;</div>

# %%
# %python
jdbcHostname="test-server25.database.windows.net"
jdbcDatabase="SQL_Database25"
jdbcusername="sqladm25"
jdbcpassword="sqladm.1*"
jdbcport="1433"
table="expedia1"
jdbcUrl="jdbc:sqlserver://{0}:{1};database={2}".format(jdbcHostname,jdbcport,jdbcDatabase)
query1= """ update incrementalinfo
set start_time = cast('{0}' as timestamp)
where tablename='expedia1'""".format(today1)
incrDf= spark.read \
.format("jdbc") \
.option("url",jdbcUrl) \
.option("dbtable",query) \
.option("user", jdbcusername) \
.option("password", jdbcpassword) \
.option("driver", "com.microsoft.sqlserver.jdbc.SQLServerDriver").option("numPartitions",10).option("partitionColumn","id") .option("lowerbound",10).option("upperbound",495944).load()
incrDf.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[4]: 20000</div>

# %%
final=spark.read.format('jdbc').options(url='jdbc:sqlserver://workspace03.sql.azuresynapse.net:1433;database=SQLPool2', dbtable= 'finalsink.expedia', user='sqladminuser' ,password='sqladm.1*').load().limit(10)
final.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[5]: 10</div>

# %%
incrDf.registerTempTable("Incrementaldata")
final.registerTempTable("finaldata")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
mergedData= spark.sql("""
select * from Incrementaldata
union all
select f.* from finaldata f anti join Incrementaldata i on i.id=f.id and i.hotel_id= f.hotel_id
""").limit(20000)
mergedData.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[10]: 20000</div>

# %%
mergedData.write.mode("overwrite").option("truncate",True).format('jdbc').options(url='jdbc:sqlserver://workspace03.sql.azuresynapse.net:1433;database=SQLPool2',dbtable= 'finalsink.expedia',
user='sqladminuser' ,password='sqladm.1*').save()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
spark.sql(query1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[13]: DataFrame[num_affected_rows: bigint]</div>

# %%
spark.sql("select * from incrementalinfo").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+-------------------+
# tablename|         start_time|
# +---------+-------------------+
#  expedia1|2021-12-16 08:04:04|
# +---------+-------------------+
#
# </div>
